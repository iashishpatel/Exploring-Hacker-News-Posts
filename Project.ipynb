# %% [markdown]
# ![file.png](data:image/png;base64,...)

# %% [markdown]
# ### In this project, I work with a data set of submissions to popular technology site Hacker News.
#
# ### I Use following skills together to complete this project
#
# - work with strings
#
# - Object-oriented programming
#
# - Dates and times

# %% [markdown]
# #### Hacker News is a site started by the startup incubator Y Combinator, where user-submitted stories (known as "posts") are voted and commented upon, similar to reddit. Hacker News is extremely popular in technology and startup circles, and posts that make it to the top of Hacker News' listings can get hundreds of thousands of visitors as a result.

# %%
from csv import reader

# %%
openfile = open("hacker_news.csv")
readfile = reader(openfile)
hn = list(readfile)
hn[1:5]
# Out:
# [['12224879',
#   'Interactive Dynamic Video',
#   'http://www.interactivedynamicvideo.com/',
#   '386',
#   '52',
#   'ne0phyte',
#   '8/4/2016 11:52'],
#  ['10975351',
#   'How to Use Open Source and Shut the Fuck Up at the Same Time',
#   'http://hueniverse.com/2016/01/26/how-to-use-open-source-and-shut-the-fuck-up-at-the-same-time/',
#   '39',
#   '10',
#   'josep2',
#   '1/26/2016 19:30'],
#  ['11964716',
#   "Florida DJs May Face Felony for April Fools' Water Joke",
#   'http://www.thewire.com/entertainment/2013/04/florida-djs-april-fools-water-joke/63798/',
#   '2',
#   '1',
#   'vezycash',
#   '6/23/2016 22:20'],
#  ['11919867',
#   'Technology ventures: From Idea to Enterprise',
#   'https://www.amazon.com/Technology-Ventures-Enterprise-Thomas-Byers/dp/0073523429',
#   '3',
#   '1',
#   'hswarna',
#   '6/17/2016 0:01']]

# %% [markdown]
# #### Extract the first row of data

# %%
headers = hn[0]
headers
# Out:
# ['id', 'title', 'url', 'num_points', 'num_comments', 'author', 'created_at']

# %%
hn = hn[1:]
hn[0:5]
# Out:
# [['12224879',
#   'Interactive Dynamic Video',
#   'http://www.interactivedynamicvideo.com/',
#   '386',
#   '52',
#   'ne0phyte',
#   '8/4/2016 11:52'],
#  ['10975351',
#   'How to Use Open Source and Shut the Fuck Up at the Same Time',
#   'http://hueniverse.com/2016/01/26/how-to-use-open-source-and-shut-the-fuck-up-at-the-same-time/',
#   '39',
#   '10',
#   'josep2',
#   '1/26/2016 19:30'],
#  ['11964716',
#   "Florida DJs May Face Felony for April Fools' Water Joke",
#   'http://www.thewire.com/entertainment/2013/04/florida-djs-april-fools-water-joke/63798/',
#   '2',
#   '1',
#   'vezycash',
#   '6/23/2016 22:20'],
#  ['11919867',
#   'Technology ventures: From Idea to Enterprise',
#   'https://www.amazon.com/Technology-Ventures-Enterprise-Thomas-Byers/dp/0073523429',
#   '3',
#   '1',
#   'hswarna',
#   '6/17/2016 0:01'],
#  ['10301696',
#   'Note by Note: The Making of Steinway L1037 (2007)',
#   'http://www.nytimes.com/2007/11/07/movies/07stein.html?_r=0',
#   '8',
#   '2',
#   'walterbell',
#   '9/30/2015 4:12']]

# %% [markdown]
# Now that we've removed the headers from hn, we're ready to filter our data Now that we've removed the headers from hn, we're ready to filter our data

# %%
ask_posts =  []
show_posts =  []
other_posts = []
for i in hn:
    title = i[1]
    title = title.lower()
    if title.startswith('ask hn') == True:
        ask_posts.append(i)
    elif title.startswith('show hn') == True:
        show_posts.append(i)
    else:
        other_posts.append(i)

# %% [markdown]
# ### Check all posts

# %%
ask_posts[0:5]
# Out:
# [['12296411',
#   'Ask HN: How to improve my personal website?',
#   '',
#   '2',
#   '6',
#   'ahmedbaracat',
#   '8/16/2016 9:55'],
#  ['10610020',
#   'Ask HN: Am I the only one outraged by Twitter shutting down share counts?',
#   '',
#   '28',
#   '29',
#   'tkfx',
#   '11/22/2015 13:43'],
#  ['11610310',
#   'Ask HN: Aby recent changes to CSS that broke mobile?',
#   '',
#   '1',
#   '1',
#   'polskibus',
#   '5/2/2016 10:14'],
#  ['12210105',
#   'Ask HN: Looking for Employee #3 How do I do it?',
#   '',
#   '1',
#   '3',
#   'sph130',
#   '8/2/2016 14:20'],
#  ['10394168',
#   'Ask HN: Someone offered to buy my browser extension from me. What now?',
#   '',
#   '28',
#   '17',
#   'roykolak',
#   '10/15/2015 16:38']]

# %%
show_posts[0:5]
# Out:
# [['10627194',
#   'Show HN: Wio Link  ESP8266 Based Web of Things Hardware Development Platform',
#   'https://iot.seeed.cc',
#   '26',
#   '22',
#   'kfihihc',
#   '11/25/2015 14:03'],
#  ['10646440',
#   'Show HN: Something pointless I made',
#   'http://dn.ht/picklecat/',
#   '747',
#   '102',
#   'dhotson',
#   '11/29/2015 22:46'],
#  ['11590768',
#   'Show HN: Shanhu.io, a programming playground powered by e8vm',
#   'https://shanhu.io',
#   '1',
#   '1',
#   'h8liu',
#   '4/28/2016 18:05'],
#  ['12178806',
#   'Show HN: Webscope  Easy way for web developers to communicate with Clients',
#   'http://webscopeapp.com',
#   '3',
#   '3',
#   'fastbrick',
#   '7/28/2016 7:11'],
#  ['10872799',
#   'Show HN: GeoScreenshot  Easily test Geo-IP based web pages',
#   'https://www.geoscreenshot.com/',
#   '1',
#   '9',
#   'kpsychwave',
#   '1/9/2016 20:45']]

# %%
other_posts[0:5]
# Out:
# [['12224879',
#   'Interactive Dynamic Video',
#   'http://www.interactivedynamicvideo.com/',
#   '386',
#   '52',
#   'ne0phyte',
#   '8/4/2016 11:52'],
#  ['10975351',
#   'How to Use Open Source and Shut the Fuck Up at the Same Time',
#   'http://hueniverse.com/2016/01/26/how-to-use-open-source-and-shut-the-fuck-up-at-the-same-time/',
#   '39',
#   '10',
#   'josep2',
#   '1/26/2016 19:30'],
#  ['11964716',
#   "Florida DJs May Face Felony for April Fools' Water Joke",
#   'http://www.thewire.com/entertainment/2013/04/florida-djs-april-fools-water-joke/63798/',
#   '2',
#   '1',
#   'vezycash',
#   '6/23/2016 22:20'],
#  ['11919867',
#   'Technology ventures: From Idea to Enterprise',
#   'https://www.amazon.com/Technology-Ventures-Enterprise-Thomas-Byers/dp/0073523429',
#   '3',
#   '1',
#   'hswarna',
#   '6/17/2016 0:01'],
#  ['10301696',
#   'Note by Note: The Making of Steinway L1037 (2007)',
#   'http://www.nytimes.com/2007/11/07/movies/07stein.html?_r=0',
#   '8',
#   '2',
#   'walterbell',
#   '9/30/2015 4:12']]

# %% [markdown]
# ### Next, let's determine if ask posts or show posts receive more comments on average.

# %% [markdown]
# #### comments on ask_posts

# %%
total_ask_comments = 0
n_comments = 0
for i in ask_posts:
    comment =  int(i[4])
    total_ask_comments += comment
    n_comments += 1

# %%
avg_ask_comments = total_ask_comments / n_comments
avg_ask_comments = float("{:.2f}".format(avg_ask_comments))
avg_ask_comments
# Out:
# 14.04

# %% [markdown]
# #### comments on show_posts

# %%
total_show_comments = 0
m_comments = 0
for i in show_posts:
    comment = int(i[4])
    total_show_comments += comment
    m_comments += 1

# %%
avg_show_comments = total_show_comments / m_comments
avg_show_comments = float("{:.2f}".format(avg_show_comments))
avg_show_comments
# Out:
# 10.32

# %% [markdown]
# ### above you should've determined that, on average, ask posts receive more comments than show posts. Since ask posts are more likely to receive comments, we'll focus our remaining analysis just on these posts.

# %% [markdown]
# ### calculating the amount of ask posts and comments by hour created. We'll use the datetime module to work with the data in the created_at column.

# %%
import datetime as dt

# %%
result_list = []
for i in ask_posts:
    created_at = i[6]
    comment = int(i[4])
    result_list.append([created_at,comment])

# %%
result_list[0:5]
# Out:
# [['8/16/2016 9:55', 6],
#  ['11/22/2015 13:43', 29],
#  ['5/2/2016 10:14', 1],
#  ['8/2/2016 14:20', 3],
#  ['10/15/2015 16:38', 17]]

# %%
counts_by_hour = {}
comments_by_hour = {}
for i in result_list:
    date_time = i[0]
    date_time = dt.datetime.strptime(date_time,"%m/%d/%Y %H:%M")
    hour = date_time.strftime('%H')
    if hour not in counts_by_hour:
        counts_by_hour[hour] = 1
        comments_by_hour[hour] = i[1]
    else:
        counts_by_hour[hour] += 1
        comments_by_hour[hour] += i[1]

# %%
counts_by_hour
# Out:
# {'09': 45,
#  '13': 85,
#  '10': 59,
#  '14': 107,
#  '16': 108,
#  '23': 68,
#  '12': 73,
#  '17': 100,
#  '15': 116,
#  '21': 109,
#  '20': 80,
#  '02': 58,
#  '18': 109,
#  '03': 54,
#  '05': 46,
#  '19': 110,
#  '01': 60,
#  '22': 71,
#  '08': 48,
#  '04': 47,
#  '00': 55,
#  '06': 44,
#  '07': 34,
#  '11': 58}

# %%
comments_by_hour
# Out:
# {'09': 251,
#  '13': 1253,
#  '10': 793,
#  '14': 1416,
#  '16': 1814,
#  '23': 543,
#  '12': 687,
#  '17': 1146,
#  '15': 4477,
#  '21': 1745,
#  '20': 1722,
#  '02': 1381,
#  '18': 1439,
#  '03': 421,
#  '05': 464,
#  '19': 1188,
#  '01': 683,
#  '22': 479,
#  '08': 492,
#  '04': 337,
#  '00': 447,
#  '06': 397,
#  '07': 267,
#  '11': 641}

# %% [markdown]
# ### Let's use this format to create a list of lists containing the hours during which posts were created and the average number of comments those posts received.

# %%
avg_by_hour = []
for i in comments_by_hour:
    avg_by_hour.append([i,comments_by_hour[i]/len(comments_by_hour)])

# %%
avg_by_hour
# Out:
# [['09', 10.458333333333334],
#  ['13', 52.208333333333336],
#  ['10', 33.041666666666664],
#  ['14', 59.0],
#  ['16', 75.58333333333333],
#  ['23', 22.625],
#  ['12', 28.625],
#  ['17', 47.75],
#  ['15', 186.54166666666666],
#  ['21', 72.70833333333333],
#  ['20', 71.75],
#  ['02', 57.541666666666664],
#  ['18', 59.958333333333336],
#  ['03', 17.541666666666668],
#  ['05', 19.333333333333332],
#  ['19', 49.5],
#  ['01', 28.458333333333332],
#  ['22', 19.958333333333332],
#  ['08', 20.5],
#  ['04', 14.041666666666666],
#  ['00', 18.625],
#  ['06', 16.541666666666668],
#  ['07', 11.125],
#  ['11', 26.708333333333332]]

# %% [markdown]
# ###  this format makes it hard to identify the hours with the highest values. Let's finish by sorting the list of lists and printing the five highest values in a format that's easier to read.

# %%
swap_avg_by_hour = []
for i in avg_by_hour:
    swap_avg_by_hour.append([i[1],i[0]])

# %%
swap_avg_by_hour
# Out:
# [[10.458333333333334, '09'],
#  [52.208333333333336, '13'],
#  [33.041666666666664, '10'],
#  [59.0, '14'],
#  [75.58333333333333, '16'],
#  [22.625, '23'],
#  [28.625, '12'],
#  [47.75, '17'],
#  [186.54166666666666, '15'],
#  [72.70833333333333, '21'],
#  [71.75, '20'],
#  [57.541666666666664, '02'],
#  [59.958333333333336, '18'],
#  [17.541666666666668, '03'],
#  [19.333333333333332, '05'],
#  [49.5, '19'],
#  [28.458333333333332, '01'],
#  [19.958333333333332, '22'],
#  [20.5, '08'],
#  [14.041666666666666, '04'],
#  [18.625, '00'],
#  [16.541666666666668, '06'],
#  [11.125, '07'],
#  [26.708333333333332, '11']]

# %%
sorted_swap = sorted(swap_avg_by_hour,reverse = True)

# %% [markdown]
# ### Top 5 Hours for Ask Posts Comments

# %%
sorted_swap[0:5]
# Out:
# [[186.54166666666666, '15'],
#  [75.58333333333333, '16'],
#  [72.70833333333333, '21'],
#  [71.75, '20'],
#  [59.958333333333336, '18']]

# %%
for i in sorted_swap:
    i[1] = dt.datetime.strptime(i[1],"%H")
    i[1] = i[1].strftime("%H: %M.%S")
    i[0] = "{:.2f}".format(i[0])
    print(f''' avg_comments | time 
        {i[0]} | {i[1]}
    
    ''')
# Out:
#  avg_comments | time
#         186.54 | 15: 00.00
#
#
#  avg_comments | time
#         75.58 | 16: 00.00
#
#
#  avg_comments | time
#         72.71 | 21: 00.00
#
#
#  avg_comments | time
#         71.75 | 20: 00.00
#
#
#  avg_comments | time
#         59.96 | 18: 00.00
#
#
#  avg_comments | time
#         59.00 | 14: 00.00
#
#
#  avg_comments | time
#         57.54 | 02: 00.00
#
#
#  avg_comments | time
#         52.21 | 13: 00.00
#
#
#  avg_comments | time
#         49.50 | 19: 00.00
#
#
#  avg_comments | time
#         47.75 | 17: 00.00
#
#
#  avg_comments | time
#         33.04 | 10: 00.00
#
#
#  avg_comments | time
#         28.62 | 12: 00.00
#
#
#  avg_comments | time
#         28.46 | 01: 00.00
#
#
#  avg_comments | time
#         26.71 | 11: 00.00
#
#
#  avg_comments | time
#         22.62 | 23: 00.00
#
#
#  avg_comments | time
#         20.50 | 08: 00.00
#
#
#  avg_comments | time
#         19.96 | 22: 00.00
#
#
#  avg_comments | time
#         19.33 | 05: 00.00
#
#
#  avg_comments | time
#         18.62 | 00: 00.00
#
#
#  avg_comments | time
#         17.54 | 03: 00.00
#
#
#  avg_comments | time
#         16.54 | 06: 00.00
#
#
#  avg_comments | time
#         14.04 | 04: 00.00
#
#
#  avg_comments | time
#         11.12 | 07: 00.00
#
#
#  avg_comments | time
#         10.46 | 09: 00.00

# %% [markdown]
# ## Creating a post at "3:PM" on "Hacker News"  have a higher chance of receiving comments

# %% [markdown]
# # So What I Cover In This Project :-
#
# ### I set a goal for the project.
# ### I collected and sorted the data.
# ### I reformatted and cleaned the data to prepare it for analysis.
# ### I analyzed the data.
